# %%
from ultralytics import YOLO

# %%
model = YOLO('yolo11n.pt')
model.train(data='C:\\Users\\aa886\\OneDrive\\Desktop\\data\\data.yaml',imgsz=640, epochs=60, batch=8,device=0)
# Out:
# Ultralytics 8.3.44  Python-3.9.12 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...
